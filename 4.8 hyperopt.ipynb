# %%
import hyperopt 
print(hyperopt.__version__)
# Out:
# 0.2.7

# %%
from hyperopt import hp 

search_space = {
    'x': hp.quniform('x', -10, 10, 1),
    'y': hp.quniform('y', -15, 15, 1),
}

# %%
from hyperopt import STATUS_OK

def objective_func(search_space):
    x = search_space['x']
    y = search_space['y']
    retval = x**2 - 20*y 

    return retval

# %%
from hyperopt import fmin, tpe, Trials
import numpy as np 

trial_val = Trials() 

best_01 = fmin(fn=objective_func, space=search_space, algo=tpe.suggest, max_evals=5, trials=trial_val, rstate=np.random.default_rng(seed=0))
print('best:', best_01)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 1666.13trial/s, best loss: -224.0]
# best: {'x': np.float64(-4.0), 'y': np.float64(12.0)}

# %%
trial_val = Trials()

best_02 = fmin(fn=objective_func, space=search_space, algo=tpe.suggest, max_evals=20, trials=trial_val, rstate=np.random.default_rng(seed=0))
print(trial_val.results)
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 1538.60trial/s, best loss: -296.0]
# [{'loss': -64.0, 'status': 'ok'}, {'loss': -184.0, 'status': 'ok'}, {'loss': 56.0, 'status': 'ok'}, {'loss': -224.0, 'status': 'ok'}, {'loss': 61.0, 'status': 'ok'}, {'loss': -296.0, 'status': 'ok'}, {'loss': -40.0, 'status': 'ok'}, {'loss': 281.0, 'status': 'ok'}, {'loss': 64.0, 'status': 'ok'}, {'loss': 100.0, 'status': 'ok'}, {'loss': 60.0, 'status': 'ok'}, {'loss': -39.0, 'status': 'ok'}, {'loss': 1.0, 'status': 'ok'}, {'loss': -164.0, 'status': 'ok'}, {'loss': 21.0, 'status': 'ok'}, {'loss': -56.0, 'status': 'ok'}, {'loss': 284.0, 'status': 'ok'}, {'loss': 176.0, 'status': 'ok'}, {'loss': -171.0, 'status': 'ok'}, {'loss': 0.0, 'status': 'ok'}]

# %%
print(trial_val.vals)
# Out:
# {'x': [np.float64(-6.0), np.float64(-4.0), np.float64(4.0), np.float64(-4.0), np.float64(9.0), np.float64(2.0), np.float64(10.0), np.float64(-9.0), np.float64(-8.0), np.float64(-0.0), np.float64(-0.0), np.float64(1.0), np.float64(9.0), np.float64(6.0), np.float64(9.0), np.float64(2.0), np.float64(-2.0), np.float64(-4.0), np.float64(7.0), np.float64(-0.0)], 'y': [np.float64(5.0), np.float64(10.0), np.float64(-2.0), np.float64(12.0), np.float64(1.0), np.float64(15.0), np.float64(7.0), np.float64(-10.0), np.float64(0.0), np.float64(-5.0), np.float64(-3.0), np.float64(2.0), np.float64(4.0), np.float64(10.0), np.float64(3.0), np.float64(3.0), np.float64(-14.0), np.float64(-8.0), np.float64(11.0), np.float64(-0.0)]}

# %%
import pandas as pd 

losses = [loss_dict['loss'] for loss_dict in trial_val.results]

result_df = pd.DataFrame({'x': trial_val.vals['x'], 'y': trial_val.vals['y'], 'losses': losses})
result_df
# Out:
#        x     y  losses
# 0   -6.0   5.0   -64.0
# 1   -4.0  10.0  -184.0
# 2    4.0  -2.0    56.0
# 3   -4.0  12.0  -224.0
# 4    9.0   1.0    61.0
# 5    2.0  15.0  -296.0
# 6   10.0   7.0   -40.0
# 7   -9.0 -10.0   281.0
# 8   -8.0   0.0    64.0
# 9   -0.0  -5.0   100.0
# 10  -0.0  -3.0    60.0
# 11   1.0   2.0   -39.0
# 12   9.0   4.0     1.0
# 13   6.0  10.0  -164.0
# 14   9.0   3.0    21.0
# 15   2.0   3.0   -56.0
# 16  -2.0 -14.0   284.0
# 17  -4.0  -8.0   176.0
# 18   7.0  11.0  -171.0
# 19  -0.0  -0.0     0.0

# %%
from sklearn.datasets import load_breast_cancer 
from sklearn.model_selection import train_test_split 

dataset = load_breast_cancer() 

cancer_df = pd.DataFrame(dataset.data, columns=dataset.feature_names)
cancer_df['target'] = dataset.target 
X_features = cancer_df.iloc[:, :-1]
y_label = cancer_df.iloc[:, -1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_features, y_label, test_size=0.2, random_state=156)

X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=156)

# %%
from hyperopt import hp 

xgb_search_space = {
    'max_depth': hp.quniform('max_depth', 5, 20, 1),
    'min_child_weight': hp.quniform('min_child_weight', 1, 2, 1),
    'learning_rate': hp.uniform('learning_rate', 0.01, 0.2),
    'colsample_bytree': hp.uniform('colsample_bytree', 0.5, 1)
}

# %%
from sklearn.model_selection import cross_val_score 
from xgboost import XGBClassifier 

def objective_func(search_space): 
    xgb_clf = XGBClassifier(n_estimators=100, max_depth=int(search_space['max_depth']), min_child_weight=int(search_space['min_child_weight']), learning_rate=search_space['learning_rate'], colsample_bytree=search_space['colsample_bytree'], eval_metric='logloss')
    accuracy = cross_val_score(xgb_clf, X_tr, y_tr, scoring='accuracy', cv=3)

    return {'loss': -1 * np.mean(accuracy), 'status': STATUS_OK}

# %%
trial_val = Trials() 
best = fmin(fn=objective_func, space=xgb_search_space, algo=tpe.suggest, max_evals=50, trials=trial_val, rstate=np.random.default_rng(seed=9))
print('best:', best)
# Out:
# 100%|██████████| 50/50 [00:06<00:00,  8.13trial/s, best loss: -0.9780127379418921]
# best: {'colsample_bytree': np.float64(0.8637740285716389), 'learning_rate': np.float64(0.10657919742273766), 'max_depth': np.float64(8.0), 'min_child_weight': np.float64(2.0)}

# %%
print(f'colsample_bytree: {best["colsample_bytree"]}')
print(f'learning_rate: {best["learning_rate"]}')
print(f'max_depth: {best["max_depth"]}')
print(f'min_child_weight: {best["min_child_weight"]}')
# Out:
# colsample_bytree: 0.8637740285716389
# learning_rate: 0.10657919742273766
# max_depth: 8.0
# min_child_weight: 2.0

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score, roc_auc_score

def get_clf_eval(y_test, pred=None, pred_proba=None):
    confusion = confusion_matrix( y_test, pred)
    accuracy = accuracy_score(y_test , pred)
    precision = precision_score(y_test , pred)
    recall = recall_score(y_test , pred)
    f1 = f1_score(y_test,pred)
    # ROC-AUC 추가 
    roc_auc = roc_auc_score(y_test, pred_proba)
    print('오차 행렬')
    print(confusion)
    # ROC-AUC print 추가
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f},\
    F1: {3:.4f}, AUC:{4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))

# %%
from lightgbm import early_stopping


xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=round(best['learning_rate'], 5), eval_metric='logloss', max_depth=int(best['max_depth']), min_child_weight=int(best['min_child_weight']), colsample_bytree=round(best['colsample_bytree'], 5), early_stopping_rounds=50)

evals = [(X_tr, y_tr), (X_val, y_val)]
xgb_wrapper.fit(X_tr, y_tr, eval_set=evals, verbose=True)

preds = xgb_wrapper.predict(X_test)
pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]

get_clf_eval(y_test, preds, pred_proba)
# Out:
# [0]	validation_0-logloss:0.58148	validation_1-logloss:0.60735
# [1]	validation_0-logloss:0.51293	validation_1-logloss:0.56948
# [2]	validation_0-logloss:0.45447	validation_1-logloss:0.52227
# [3]	validation_0-logloss:0.40544	validation_1-logloss:0.48525
# [4]	validation_0-logloss:0.36422	validation_1-logloss:0.45206
# [5]	validation_0-logloss:0.32900	validation_1-logloss:0.42505
# [6]	validation_0-logloss:0.29748	validation_1-logloss:0.40527
# [7]	validation_0-logloss:0.27132	validation_1-logloss:0.38587
# [8]	validation_0-logloss:0.24638	validation_1-logloss:0.36906
# [9]	validation_0-logloss:0.22635	validation_1-logloss:0.35576
# [10]	validation_0-logloss:0.20691	validation_1-logloss:0.34055
# [11]	validation_0-logloss:0.19028	validation_1-logloss:0.33020
# [12]	validation_0-logloss:0.17568	validation_1-logloss:0.32350
# [13]	validation_0-logloss:0.16282	validation_1-logloss:0.31550
# [14]	validation_0-logloss:0.15096	validation_1-logloss:0.30866
# [15]	validation_0-logloss:0.14009	validation_1-logloss:0.30236
# [16]	validation_0-logloss:0.13060	validation_1-logloss:0.29841
# [17]	validation_0-logloss:0.12257	validation_1-logloss:0.29373
# [18]	validation_0-logloss:0.11451	validation_1-logloss:0.28894
# [19]	validation_0-logloss:0.10763	validation_1-logloss:0.28717
# [20]	validation_0-logloss:0.10088	validation_1-logloss:0.28384
# [21]	validation_0-logloss:0.09469	validation_1-logloss:0.27883
# [22]	validation_0-logloss:0.08982	validation_1-logloss:0.27945
# [23]	validation_0-logloss:0.08492	validation_1-logloss:0.27802
# [24]	validation_0-logloss:0.07980	validation_1-logloss:0.27501
# [25]	validation_0-logloss:0.07608	validation_1-logloss:0.27471
# [26]	validation_0-logloss:0.07174	validation_1-logloss:0.27368
# [27]	validation_0-logloss:0.06867	validation_1-logloss:0.27423
# [28]	validation_0-logloss:0.06589	validation_1-logloss:0.27242
# [29]	validation_0-logloss:0.06254	validation_1-logloss:0.27016
# [30]	validation_0-logloss:0.05934	validation_1-logloss:0.26716
# [31]	validation_0-logloss:0.05657	validation_1-logloss:0.26529
# [32]	validation_0-logloss:0.05429	validation_1-logloss:0.26623
# [33]	validation_0-logloss:0.05165	validation_1-logloss:0.26618
# [34]	validation_0-logloss:0.04934	validation_1-logloss:0.26198
# [35]	validation_0-logloss:0.04738	validation_1-logloss:0.26422
# [36]	validation_0-logloss:0.04535	validation_1-logloss:0.26539
# [37]	validation_0-logloss:0.04346	validation_1-logloss:0.26454
# [38]	validation_0-logloss:0.04233	validation_1-logloss:0.26258
# [39]	validation_0-logloss:0.04077	validation_1-logloss:0.26227
# [40]	validation_0-logloss:0.03920	validation_1-logloss:0.26345
# [41]	validation_0-logloss:0.03782	validation_1-logloss:0.26360
# [42]	validation_0-logloss:0.03655	validation_1-logloss:0.26634
# [43]	validation_0-logloss:0.03557	validation_1-logloss:0.26861
# [44]	validation_0-logloss:0.03456	validation_1-logloss:0.26872
# [45]	validation_0-logloss:0.03337	validation_1-logloss:0.27049
# [46]	validation_0-logloss:0.03269	validation_1-logloss:0.26771
# [47]	validation_0-logloss:0.03186	validation_1-logloss:0.26833
# [48]	validation_0-logloss:0.03088	validation_1-logloss:0.26994
# [49]	validation_0-logloss:0.03025	validation_1-logloss:0.26904
# [50]	validation_0-logloss:0.02944	validation_1-logloss:0.26909
# [51]	validation_0-logloss:0.02884	validation_1-logloss:0.26986
# [52]	validation_0-logloss:0.02829	validation_1-logloss:0.26780
# [53]	validation_0-logloss:0.02780	validation_1-logloss:0.26634
# [54]	validation_0-logloss:0.02728	validation_1-logloss:0.26683
# [55]	validation_0-logloss:0.02689	validation_1-logloss:0.26711
# [56]	validation_0-logloss:0.02642	validation_1-logloss:0.26713
# [57]	validation_0-logloss:0.02602	validation_1-logloss:0.26579
# [58]	validation_0-logloss:0.02560	validation_1-logloss:0.26664
# [59]	validation_0-logloss:0.02524	validation_1-logloss:0.26527
# [60]	validation_0-logloss:0.02492	validation_1-logloss:0.26410
# [61]	validation_0-logloss:0.02453	validation_1-logloss:0.26459
# [62]	validation_0-logloss:0.02422	validation_1-logloss:0.26329
# [63]	validation_0-logloss:0.02387	validation_1-logloss:0.26379
# [64]	validation_0-logloss:0.02360	validation_1-logloss:0.26413
# [65]	validation_0-logloss:0.02317	validation_1-logloss:0.26261
# [66]	validation_0-logloss:0.02303	validation_1-logloss:0.26248
# [67]	validation_0-logloss:0.02280	validation_1-logloss:0.26322
# [68]	validation_0-logloss:0.02266	validation_1-logloss:0.26210
# [69]	validation_0-logloss:0.02241	validation_1-logloss:0.26265
# [70]	validation_0-logloss:0.02229	validation_1-logloss:0.26254
# [71]	validation_0-logloss:0.02190	validation_1-logloss:0.25983
# [72]	validation_0-logloss:0.02178	validation_1-logloss:0.25973
# [73]	validation_0-logloss:0.02165	validation_1-logloss:0.26121
# [74]	validation_0-logloss:0.02153	validation_1-logloss:0.26109
# [75]	validation_0-logloss:0.02141	validation_1-logloss:0.26000
# [76]	validation_0-logloss:0.02115	validation_1-logloss:0.26063
# [77]	validation_0-logloss:0.02103	validation_1-logloss:0.26213
# [78]	validation_0-logloss:0.02092	validation_1-logloss:0.26111
# [79]	validation_0-logloss:0.02081	validation_1-logloss:0.26254
# [80]	validation_0-logloss:0.02071	validation_1-logloss:0.26246
# [81]	validation_0-logloss:0.02061	validation_1-logloss:0.26148
# [82]	validation_0-logloss:0.02051	validation_1-logloss:0.26287
# [83]	validation_0-logloss:0.02040	validation_1-logloss:0.26275
# [84]	validation_0-logloss:0.02031	validation_1-logloss:0.26408
# [85]	validation_0-logloss:0.02022	validation_1-logloss:0.26312
# [86]	validation_0-logloss:0.02012	validation_1-logloss:0.26305
# [87]	validation_0-logloss:0.02004	validation_1-logloss:0.26297
# [88]	validation_0-logloss:0.01995	validation_1-logloss:0.26428
# [89]	validation_0-logloss:0.01986	validation_1-logloss:0.26336
# [90]	validation_0-logloss:0.01978	validation_1-logloss:0.26325
# [91]	validation_0-logloss:0.01969	validation_1-logloss:0.26164
# [92]	validation_0-logloss:0.01961	validation_1-logloss:0.26295
# [93]	validation_0-logloss:0.01953	validation_1-logloss:0.26109
# [94]	validation_0-logloss:0.01945	validation_1-logloss:0.26146
# [95]	validation_0-logloss:0.01937	validation_1-logloss:0.26140
# [96]	validation_0-logloss:0.01929	validation_1-logloss:0.26053
# [97]	validation_0-logloss:0.01921	validation_1-logloss:0.26183
# [98]	validation_0-logloss:0.01914	validation_1-logloss:0.26173
# [99]	validation_0-logloss:0.01906	validation_1-logloss:0.26021
# [100]	validation_0-logloss:0.01899	validation_1-logloss:0.26147
# [101]	validation_0-logloss:0.01891	validation_1-logloss:0.25967
# [102]	validation_0-logloss:0.01884	validation_1-logloss:0.26003
# [103]	validation_0-logloss:0.01877	validation_1-logloss:0.25919
# [104]	validation_0-logloss:0.01870	validation_1-logloss:0.26042
# [105]	validation_0-logloss:0.01863	validation_1-logloss:0.26037
# [106]	validation_0-logloss:0.01856	validation_1-logloss:0.25956
# [107]	validation_0-logloss:0.01849	validation_1-logloss:0.25991
# [108]	validation_0-logloss:0.01843	validation_1-logloss:0.25819
# [109]	validation_0-logloss:0.01836	validation_1-logloss:0.25941
# [110]	validation_0-logloss:0.01829	validation_1-logloss:0.25796
# [111]	validation_0-logloss:0.01823	validation_1-logloss:0.25787
# [112]	validation_0-logloss:0.01816	validation_1-logloss:0.25925
# [113]	validation_0-logloss:0.01810	validation_1-logloss:0.25997
# [114]	validation_0-logloss:0.01803	validation_1-logloss:0.25824
# [115]	validation_0-logloss:0.01797	validation_1-logloss:0.25749
# [116]	validation_0-logloss:0.01791	validation_1-logloss:0.25869
# [117]	validation_0-logloss:0.01785	validation_1-logloss:0.25860
# [118]	validation_0-logloss:0.01779	validation_1-logloss:0.25813
# [119]	validation_0-logloss:0.01773	validation_1-logloss:0.25654
# [120]	validation_0-logloss:0.01767	validation_1-logloss:0.25727
# [121]	validation_0-logloss:0.01761	validation_1-logloss:0.25721
# [122]	validation_0-logloss:0.01756	validation_1-logloss:0.25838
# [123]	validation_0-logloss:0.01750	validation_1-logloss:0.25764
# [124]	validation_0-logloss:0.01744	validation_1-logloss:0.25632
# [125]	validation_0-logloss:0.01739	validation_1-logloss:0.25702
# [126]	validation_0-logloss:0.01733	validation_1-logloss:0.25544
# [127]	validation_0-logloss:0.01728	validation_1-logloss:0.25536
# [128]	validation_0-logloss:0.01722	validation_1-logloss:0.25666
# [129]	validation_0-logloss:0.01717	validation_1-logloss:0.25516
# [130]	validation_0-logloss:0.01712	validation_1-logloss:0.25587
# [131]	validation_0-logloss:0.01707	validation_1-logloss:0.25543
# [132]	validation_0-logloss:0.01702	validation_1-logloss:0.25535
# [133]	validation_0-logloss:0.01697	validation_1-logloss:0.25526
# [134]	validation_0-logloss:0.01692	validation_1-logloss:0.25375
# [135]	validation_0-logloss:0.01687	validation_1-logloss:0.25503
# [136]	validation_0-logloss:0.01682	validation_1-logloss:0.25571
# [137]	validation_0-logloss:0.01677	validation_1-logloss:0.25422
# [138]	validation_0-logloss:0.01672	validation_1-logloss:0.25428
# [139]	validation_0-logloss:0.01667	validation_1-logloss:0.25385
# [140]	validation_0-logloss:0.01663	validation_1-logloss:0.25378
# [141]	validation_0-logloss:0.01658	validation_1-logloss:0.25311
# [142]	validation_0-logloss:0.01653	validation_1-logloss:0.25433
# [143]	validation_0-logloss:0.01649	validation_1-logloss:0.25294
# [144]	validation_0-logloss:0.01644	validation_1-logloss:0.25286
# [145]	validation_0-logloss:0.01640	validation_1-logloss:0.25280
# [146]	validation_0-logloss:0.01636	validation_1-logloss:0.25327
# [147]	validation_0-logloss:0.01631	validation_1-logloss:0.25263
# [148]	validation_0-logloss:0.01627	validation_1-logloss:0.25255
# [149]	validation_0-logloss:0.01623	validation_1-logloss:0.25263
# [150]	validation_0-logloss:0.01618	validation_1-logloss:0.25124
# [151]	validation_0-logloss:0.01614	validation_1-logloss:0.25244
# [152]	validation_0-logloss:0.01610	validation_1-logloss:0.25114
# [153]	validation_0-logloss:0.01606	validation_1-logloss:0.25124
# [154]	validation_0-logloss:0.01602	validation_1-logloss:0.25173
# [155]	validation_0-logloss:0.01597	validation_1-logloss:0.25164
# [156]	validation_0-logloss:0.01593	validation_1-logloss:0.25103
# [157]	validation_0-logloss:0.01589	validation_1-logloss:0.25061
# [158]	validation_0-logloss:0.01585	validation_1-logloss:0.25057
# [159]	validation_0-logloss:0.01582	validation_1-logloss:0.25049
# [160]	validation_0-logloss:0.01578	validation_1-logloss:0.24990
# [161]	validation_0-logloss:0.01574	validation_1-logloss:0.25036
# [162]	validation_0-logloss:0.01570	validation_1-logloss:0.24910
# [163]	validation_0-logloss:0.01566	validation_1-logloss:0.25024
# [164]	validation_0-logloss:0.01562	validation_1-logloss:0.25016
# [165]	validation_0-logloss:0.01559	validation_1-logloss:0.25065
# [166]	validation_0-logloss:0.01555	validation_1-logloss:0.25053
# [167]	validation_0-logloss:0.01551	validation_1-logloss:0.25064
# [168]	validation_0-logloss:0.01547	validation_1-logloss:0.24937
# [169]	validation_0-logloss:0.01544	validation_1-logloss:0.24949
# [170]	validation_0-logloss:0.01540	validation_1-logloss:0.24892
# [171]	validation_0-logloss:0.01537	validation_1-logloss:0.24882
# [172]	validation_0-logloss:0.01533	validation_1-logloss:0.24993
# [173]	validation_0-logloss:0.01530	validation_1-logloss:0.24938
# [174]	validation_0-logloss:0.01526	validation_1-logloss:0.24983
# [175]	validation_0-logloss:0.01523	validation_1-logloss:0.24943
# [176]	validation_0-logloss:0.01519	validation_1-logloss:0.24956
# [177]	validation_0-logloss:0.01516	validation_1-logloss:0.24836
# [178]	validation_0-logloss:0.01512	validation_1-logloss:0.24827
# [179]	validation_0-logloss:0.01509	validation_1-logloss:0.24934
# [180]	validation_0-logloss:0.01506	validation_1-logloss:0.24820
# [181]	validation_0-logloss:0.01503	validation_1-logloss:0.24833
# [182]	validation_0-logloss:0.01499	validation_1-logloss:0.24823
# [183]	validation_0-logloss:0.01496	validation_1-logloss:0.24872
# [184]	validation_0-logloss:0.01493	validation_1-logloss:0.24834
# [185]	validation_0-logloss:0.01490	validation_1-logloss:0.24782
# [186]	validation_0-logloss:0.01487	validation_1-logloss:0.24796
# [187]	validation_0-logloss:0.01484	validation_1-logloss:0.24685
# [188]	validation_0-logloss:0.01480	validation_1-logloss:0.24731
# [189]	validation_0-logloss:0.01477	validation_1-logloss:0.24720
# [190]	validation_0-logloss:0.01474	validation_1-logloss:0.24735
# [191]	validation_0-logloss:0.01471	validation_1-logloss:0.24684
# [192]	validation_0-logloss:0.01468	validation_1-logloss:0.24788
# [193]	validation_0-logloss:0.01465	validation_1-logloss:0.24681
# [194]	validation_0-logloss:0.01462	validation_1-logloss:0.24726
# [195]	validation_0-logloss:0.01460	validation_1-logloss:0.24680
# [196]	validation_0-logloss:0.01457	validation_1-logloss:0.24663
# [197]	validation_0-logloss:0.01454	validation_1-logloss:0.24679
# [198]	validation_0-logloss:0.01451	validation_1-logloss:0.24576
# [199]	validation_0-logloss:0.01449	validation_1-logloss:0.24621
# [200]	validation_0-logloss:0.01445	validation_1-logloss:0.24608
# [201]	validation_0-logloss:0.01443	validation_1-logloss:0.24624
# [202]	validation_0-logloss:0.01440	validation_1-logloss:0.24613
# [203]	validation_0-logloss:0.01437	validation_1-logloss:0.24714
# [204]	validation_0-logloss:0.01435	validation_1-logloss:0.24668
# [205]	validation_0-logloss:0.01432	validation_1-logloss:0.24632
# [206]	validation_0-logloss:0.01430	validation_1-logloss:0.24680
# [207]	validation_0-logloss:0.01427	validation_1-logloss:0.24668
# [208]	validation_0-logloss:0.01424	validation_1-logloss:0.24685
# [209]	validation_0-logloss:0.01422	validation_1-logloss:0.24647
# [210]	validation_0-logloss:0.01420	validation_1-logloss:0.24742
# [211]	validation_0-logloss:0.01417	validation_1-logloss:0.24699
# [212]	validation_0-logloss:0.01415	validation_1-logloss:0.24688
# [213]	validation_0-logloss:0.01412	validation_1-logloss:0.24705
# [214]	validation_0-logloss:0.01410	validation_1-logloss:0.24664
# [215]	validation_0-logloss:0.01407	validation_1-logloss:0.24712
# [216]	validation_0-logloss:0.01405	validation_1-logloss:0.24702
# [217]	validation_0-logloss:0.01403	validation_1-logloss:0.24667
# [218]	validation_0-logloss:0.01400	validation_1-logloss:0.24684
# [219]	validation_0-logloss:0.01398	validation_1-logloss:0.24730
# [220]	validation_0-logloss:0.01396	validation_1-logloss:0.24689
# [221]	validation_0-logloss:0.01394	validation_1-logloss:0.24678
# [222]	validation_0-logloss:0.01392	validation_1-logloss:0.24770
# [223]	validation_0-logloss:0.01390	validation_1-logloss:0.24737
# [224]	validation_0-logloss:0.01387	validation_1-logloss:0.24755
# [225]	validation_0-logloss:0.01385	validation_1-logloss:0.24716
# [226]	validation_0-logloss:0.01383	validation_1-logloss:0.24706
# [227]	validation_0-logloss:0.01381	validation_1-logloss:0.24751
# [228]	validation_0-logloss:0.01379	validation_1-logloss:0.24761
# [229]	validation_0-logloss:0.01377	validation_1-logloss:0.24723
# [230]	validation_0-logloss:0.01375	validation_1-logloss:0.24812
# [231]	validation_0-logloss:0.01373	validation_1-logloss:0.24803
# [232]	validation_0-logloss:0.01371	validation_1-logloss:0.24821
# [233]	validation_0-logloss:0.01369	validation_1-logloss:0.24785
# [234]	validation_0-logloss:0.01367	validation_1-logloss:0.24776
# [235]	validation_0-logloss:0.01365	validation_1-logloss:0.24739
# [236]	validation_0-logloss:0.01363	validation_1-logloss:0.24826
# [237]	validation_0-logloss:0.01362	validation_1-logloss:0.24869
# [238]	validation_0-logloss:0.01360	validation_1-logloss:0.24888
# [239]	validation_0-logloss:0.01358	validation_1-logloss:0.24856
# [240]	validation_0-logloss:0.01356	validation_1-logloss:0.24847
# [241]	validation_0-logloss:0.01354	validation_1-logloss:0.24812
# [242]	validation_0-logloss:0.01352	validation_1-logloss:0.24830
# [243]	validation_0-logloss:0.01351	validation_1-logloss:0.24872
# [244]	validation_0-logloss:0.01349	validation_1-logloss:0.24838
# [245]	validation_0-logloss:0.01347	validation_1-logloss:0.24821
# [246]	validation_0-logloss:0.01345	validation_1-logloss:0.24787
# [247]	validation_0-logloss:0.01343	validation_1-logloss:0.24778
# [248]	validation_0-logloss:0.01342	validation_1-logloss:0.24819
# 오차 행렬
# [[35  2]
#  [ 2 75]]
# 정확도: 0.9649, 정밀도: 0.9740, 재현율: 0.9740,    F1: 0.9740, AUC:0.9944
